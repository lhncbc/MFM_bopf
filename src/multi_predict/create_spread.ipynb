# %%
import pandas as pd
import os
import glob

pd.options.display.max_columns = None
pd.options.display.max_rows = None

os.chdir('/slurm_storage/mbopf/projects/MFM_bopf/src/multi_predict/output')
#os.chdir('/MFMDatasets/MFM_bopf/src/multi_predict/NB/output')
#os.chdir('/MFMDatasets/MFM_bopf/src/multi_predict/LR/output')
#os.chdir('/MFMDatasets/MFM_bopf/src/multi_predict/LR/output/old')
#os.chdir('/MFMDatasets/MFM_bopf/src/multi_predict/RF/output')
#os.chdir('/MFMDatasets/MFM_bopf/src/multi_predict/SVC/output')
#os.chdir('/MFMDatasets/MFM_bopf/src/multi_predict/LSVC/output')
#os.chdir('/MFMDatasets/MFM_bopf/src/multi_predict/MLP/output')
results_df = pd.DataFrame()
#files = glob.glob("*-NB-*.csv")
files = glob.glob("*-LR-*.csv")
#files = glob.glob("*-RF-*.csv")
#files = glob.glob("*-SVC-*.csv")
#files = glob.glob("*-LSVC-*.csv")
#files = glob.glob("*-MLP-*.csv")
files.sort(key=os.path.getmtime)
for idx, f in enumerate(files):
    if results_df.empty:
        results_df = pd.read_csv(f, header=None, index_col=0, names=[idx])
    else:
        this_df = pd.read_csv(f, header=None, index_col=0, names=[idx])
        results_df = results_df.merge(this_df, left_index=True, right_index=True, how="right")
results_df
# Out:
#                            0             1             2             3   \
# CLF_time(min)           0.007         0.009         0.008         0.003
# target           transfus_yes  transfus_yes  transfus_yes  transfus_yes
# under_alg                RAND          RAND          RAND          RAND
# pred_alg                   LR            LR            LR            LR
# seed                        7             7             7             7
# samp_strat                1.0           1.0           1.0           1.0
# p_C                       100           100           100          1000
# p_max_iter                 10           100          1000            10
# p_random_state              7             7             7             7
# p_solver            liblinear     liblinear     liblinear     liblinear
# TN                      41404         40478         40478         41404
# FP                      12669         13595         13595         12669
# FN                        320           206           206           320
# TP                       1231          1345          1345          1231
# precision_2             0.089         0.090         0.090         0.089
# recall_2                0.794         0.867         0.867         0.794
# F1_2                    0.159         0.163         0.163         0.159
# precision_macro         0.540         0.542         0.542         0.540
# recall_macro            0.780         0.808         0.808         0.780
# F1_macro                0.512         0.509         0.509         0.512
# ROC_AUC                 0.780         0.808         0.808         0.780
# PR_AUC                  0.088         0.137         0.137         0.088
# MCC                     0.213         0.229         0.229         0.213
# Combo                   0.511         0.522         0.522         0.511
#
#                            4             5             6             7   \
# CLF_time(min)           0.009         0.009         0.005         0.009
# target           transfus_yes  transfus_yes  transfus_yes  transfus_yes
# under_alg                RAND          RAND          RAND          RAND
# pred_alg                   LR            LR            LR            LR
# seed                        7             7             7             7
# samp_strat                1.0           1.0           1.0           1.0
# p_C                      1000          1000           100           100
# p_max_iter                100          1000            10           100
# p_random_state              7             7             7             7
# p_solver            liblinear     liblinear     liblinear     liblinear
# TN                      40513         40513         41404         40478
# FP                      13560         13560         12669         13595
# FN                        205           205           320           206
# TP                       1346          1346          1231          1345
# precision_2             0.090         0.090         0.089         0.090
# recall_2                0.868         0.868         0.794         0.867
# F1_2                    0.164         0.164         0.159         0.163
# precision_macro         0.543         0.543         0.540         0.542
# recall_macro            0.809         0.809         0.780         0.808
# F1_macro                0.509         0.509         0.512         0.509
# ROC_AUC                 0.809         0.809         0.780         0.808
# PR_AUC                  0.138         0.138         0.088         0.137
# MCC                     0.229         0.229         0.213         0.229
# Combo                   0.522         0.522         0.511         0.522
#
#                            8             9             10            11  \
# CLF_time(min)           0.008         0.003         0.009         0.009
# target           transfus_yes  transfus_yes  transfus_yes  transfus_yes
# under_alg                RAND          RAND          RAND          RAND
# pred_alg                   LR            LR            LR            LR
# seed                        7             7             7             7
# samp_strat                1.0           1.0           1.0           1.0
# p_C                       100          1000          1000          1000
# p_max_iter               1000            10           100          1000
# p_random_state              7             7             7             7
# p_solver            liblinear     liblinear     liblinear     liblinear
# TN                      40478         41404         40513         40513
# FP                      13595         12669         13560         13560
# FN                        206           320           205           205
# TP                       1345          1231          1346          1346
# precision_2             0.090         0.089         0.090         0.090
# recall_2                0.867         0.794         0.868         0.868
# F1_2                    0.163         0.159         0.164         0.164
# precision_macro         0.542         0.540         0.543         0.543
# recall_macro            0.808         0.780         0.809         0.809
# F1_macro                0.509         0.512         0.509         0.509
# ROC_AUC                 0.808         0.780         0.809         0.809
# PR_AUC                  0.137         0.088         0.138         0.138
# MCC                     0.229         0.213         0.229         0.229
# Combo                   0.522         0.511         0.522         0.522
#
#                            12            13            14            15  \
# CLF_time(min)           0.005         0.006         0.012         0.013
# target           transfus_yes  transfus_yes  transfus_yes  transfus_yes
# under_alg                RAND          RAND          RAND          RAND
# pred_alg                   LR            LR            LR            LR
# seed                        7             7             7             7
# samp_strat                1.0           1.0           1.0           1.0
# p_C                       100          1000           100           100
# p_max_iter                 10            10           100          1000
# p_random_state              7             7             7             7
# p_solver            liblinear     liblinear     liblinear     liblinear
# TN                      41404         41404         40478         40478
# FP                      12669         12669         13595         13595
# FN                        320           320           206           206
# TP                       1231          1231          1345          1345
# precision_2             0.089         0.089         0.090         0.090
# recall_2                0.794         0.794         0.867         0.867
# F1_2                    0.159         0.159         0.163         0.163
# precision_macro         0.540         0.540         0.542         0.542
# recall_macro            0.780         0.780         0.808         0.808
# F1_macro                0.512         0.512         0.509         0.509
# ROC_AUC                 0.780         0.780         0.808         0.808
# PR_AUC                  0.088         0.088         0.137         0.137
# MCC                     0.213         0.213         0.229         0.229
# Combo                   0.511         0.511         0.522         0.522
#
#                            16            17            18            19  \
# CLF_time(min)           0.013         0.010         0.005         0.014
# target           transfus_yes  transfus_yes  transfus_yes  transfus_yes
# under_alg                RAND          RAND          RAND          RAND
# pred_alg                   LR            LR            LR            LR
# seed                        7             7             7             7
# samp_strat                1.0           1.0           1.0           1.0
# p_C                      1000          1000           100           100
# p_max_iter                100          1000            10           100
# p_random_state              7             7             7             7
# p_solver            liblinear     liblinear     liblinear     liblinear
# TN                      40513         40513         41404         40478
# FP                      13560         13560         12669         13595
# FN                        205           205           320           206
# TP                       1346          1346          1231          1345
# precision_2             0.090         0.090         0.089         0.090
# recall_2                0.868         0.868         0.794         0.867
# F1_2                    0.164         0.164         0.159         0.163
# precision_macro         0.543         0.543         0.540         0.542
# recall_macro            0.809         0.809         0.780         0.808
# F1_macro                0.509         0.509         0.512         0.509
# ROC_AUC                 0.809         0.809         0.780         0.808
# PR_AUC                  0.138         0.138         0.088         0.137
# MCC                     0.229         0.229         0.213         0.229
# Combo                   0.522         0.522         0.511         0.522
#
#                            20            21            22            23  \
# CLF_time(min)           0.012         0.009         0.009         0.009
# target           transfus_yes  transfus_yes  transfus_yes  transfus_yes
# under_alg                RAND          RAND          RAND          RAND
# pred_alg                   LR            LR            LR            LR
# seed                        7             7             7             7
# samp_strat                1.0           1.0           1.0           1.0
# p_C                       100          1000          1000          1000
# p_max_iter               1000            10           100          1000
# p_random_state              7             7             7             7
# p_solver            liblinear     liblinear     liblinear     liblinear
# TN                      40478         41404         40513         40513
# FP                      13595         12669         13560         13560
# FN                        206           320           205           205
# TP                       1345          1231          1346          1346
# precision_2             0.090         0.089         0.090         0.090
# recall_2                0.867         0.794         0.868         0.868
# F1_2                    0.163         0.159         0.164         0.164
# precision_macro         0.542         0.540         0.543         0.543
# recall_macro            0.808         0.780         0.809         0.809
# F1_macro                0.509         0.512         0.509         0.509
# ROC_AUC                 0.808         0.780         0.809         0.809
# PR_AUC                  0.137         0.088         0.138         0.138
# MCC                     0.229         0.213         0.229         0.229
# Combo                   0.522         0.511         0.522         0.522
#
#                            24            25            26            27  \
# CLF_time(min)           0.011         0.010         0.011         0.012
# target           transfus_yes  transfus_yes  transfus_yes  transfus_yes
# under_alg                RAND          RAND          RAND          RAND
# pred_alg                   LR            LR            LR            LR
# seed                        7             7             7             7
# samp_strat                1.0           1.0           1.0           1.0
# p_C                       100           100           100          1000
# p_max_iter              10000        100000       1000000         10000
# p_random_state              7             7             7             7
# p_solver            liblinear     liblinear     liblinear     liblinear
# TN                      40478         40478         40478         40513
# FP                      13595         13595         13595         13560
# FN                        206           206           206           205
# TP                       1345          1345          1345          1346
# precision_2             0.090         0.090         0.090         0.090
# recall_2                0.867         0.867         0.867         0.868
# F1_2                    0.163         0.163         0.163         0.164
# precision_macro         0.542         0.542         0.542         0.543
# recall_macro            0.808         0.808         0.808         0.809
# F1_macro                0.509         0.509         0.509         0.509
# ROC_AUC                 0.808         0.808         0.808         0.809
# PR_AUC                  0.137         0.137         0.137         0.138
# MCC                     0.229         0.229         0.229         0.229
# Combo                   0.522         0.522         0.522         0.522
#
#                            28            29            30            31  \
# CLF_time(min)           0.010         0.011         0.011         0.013
# target           transfus_yes  transfus_yes  transfus_yes  transfus_yes
# under_alg                RAND          RAND          RAND          RAND
# pred_alg                   LR            LR            LR            LR
# seed                        7             7             7             7
# samp_strat                1.0           1.0           1.0           1.0
# p_C                      1000          1000           100           100
# p_max_iter             100000       1000000         10000        100000
# p_random_state              7             7             7             7
# p_solver            liblinear     liblinear     liblinear     liblinear
# TN                      40513         40513         40478         40478
# FP                      13560         13560         13595         13595
# FN                        205           205           206           206
# TP                       1346          1346          1345          1345
# precision_2             0.090         0.090         0.090         0.090
# recall_2                0.868         0.868         0.867         0.867
# F1_2                    0.164         0.164         0.163         0.163
# precision_macro         0.543         0.543         0.542         0.542
# recall_macro            0.809         0.809         0.808         0.808
# F1_macro                0.509         0.509         0.509         0.509
# ROC_AUC                 0.809         0.809         0.808         0.808
# PR_AUC                  0.138         0.138         0.137         0.137
# MCC                     0.229         0.229         0.229         0.229
# Combo                   0.522         0.522         0.522         0.522
#
#                            32            33            34            35  \
# CLF_time(min)           0.012         0.013         0.010         0.010
# target           transfus_yes  transfus_yes  transfus_yes  transfus_yes
# under_alg                RAND          RAND          RAND          RAND
# pred_alg                   LR            LR            LR            LR
# seed                        7             7             7             7
# samp_strat                1.0           1.0           1.0           1.0
# p_C                       100          1000          1000          1000
# p_max_iter            1000000         10000        100000       1000000
# p_random_state              7             7             7             7
# p_solver            liblinear     liblinear     liblinear     liblinear
# TN                      40478         40513         40513         40513
# FP                      13595         13560         13560         13560
# FN                        206           205           205           205
# TP                       1345          1346          1346          1346
# precision_2             0.090         0.090         0.090         0.090
# recall_2                0.867         0.868         0.868         0.868
# F1_2                    0.163         0.164         0.164         0.164
# precision_macro         0.542         0.543         0.543         0.543
# recall_macro            0.808         0.809         0.809         0.809
# F1_macro                0.509         0.509         0.509         0.509
# ROC_AUC                 0.808         0.809         0.809         0.809
# PR_AUC                  0.137         0.138         0.138         0.138
# MCC                     0.229         0.229         0.229         0.229
# Combo                   0.522         0.522         0.522         0.522
#
#                            36            37            38            39  \
# CLF_time(min)           0.010         0.013         0.013         0.013
# target           transfus_yes  transfus_yes  transfus_yes  transfus_yes
# under_alg                RAND          RAND          RAND          RAND
# pred_alg                   LR            LR            LR            LR
# seed                        7             7             7             7
# samp_strat                1.0           1.0           1.0           1.0
# p_C                       100           100           100          1000
# p_max_iter              10000        100000       1000000         10000
# p_random_state              7             7             7             7
# p_solver            liblinear     liblinear     liblinear     liblinear
# TN                      40478         40478         40478         40513
# FP                      13595         13595         13595         13560
# FN                        206           206           206           205
# TP                       1345          1345          1345          1346
# precision_2             0.090         0.090         0.090         0.090
# recall_2                0.867         0.867         0.867         0.868
# F1_2                    0.163         0.163         0.163         0.164
# precision_macro         0.542         0.542         0.542         0.543
# recall_macro            0.808         0.808         0.808         0.809
# F1_macro                0.509         0.509         0.509         0.509
# ROC_AUC                 0.808         0.808         0.808         0.809
# PR_AUC                  0.137         0.137         0.137         0.138
# MCC                     0.229         0.229         0.229         0.229
# Combo                   0.522         0.522         0.522         0.522
#
#                            40            41
# CLF_time(min)           0.011         0.009
# target           transfus_yes  transfus_yes
# under_alg                RAND          RAND
# pred_alg                   LR            LR
# seed                        7             7
# samp_strat                1.0           1.0
# p_C                      1000          1000
# p_max_iter             100000       1000000
# p_random_state              7             7
# p_solver            liblinear     liblinear
# TN                      40513         40513
# FP                      13560         13560
# FN                        205           205
# TP                       1346          1346
# precision_2             0.090         0.090
# recall_2                0.868         0.868
# F1_2                    0.164         0.164
# precision_macro         0.543         0.543
# recall_macro            0.809         0.809
# F1_macro                0.509         0.509
# ROC_AUC                 0.809         0.809
# PR_AUC                  0.138         0.138
# MCC                     0.229         0.229
# Combo                   0.522         0.522

# %%
results_T = results_df.T
#results_T[results_T['p_kernel']=='poly'].sort_values(by=['p_kernel','Combo'], ascending=False)
results_T.sort_values(by=['Combo'], ascending=False, inplace=True)
results_T
# Out:
#    CLF_time(min)        target under_alg pred_alg seed samp_strat   p_C  \
# 41         0.009  transfus_yes      RAND       LR    7        1.0  1000
# 25         0.010  transfus_yes      RAND       LR    7        1.0   100
# 19         0.014  transfus_yes      RAND       LR    7        1.0   100
# 20         0.012  transfus_yes      RAND       LR    7        1.0   100
# 1          0.009  transfus_yes      RAND       LR    7        1.0   100
# 22         0.009  transfus_yes      RAND       LR    7        1.0  1000
# 23         0.009  transfus_yes      RAND       LR    7        1.0  1000
# 24         0.011  transfus_yes      RAND       LR    7        1.0   100
# 26         0.011  transfus_yes      RAND       LR    7        1.0   100
# 34         0.010  transfus_yes      RAND       LR    7        1.0  1000
# 27         0.012  transfus_yes      RAND       LR    7        1.0  1000
# 28         0.010  transfus_yes      RAND       LR    7        1.0  1000
# 29         0.011  transfus_yes      RAND       LR    7        1.0  1000
# 30         0.011  transfus_yes      RAND       LR    7        1.0   100
# 31         0.013  transfus_yes      RAND       LR    7        1.0   100
# 32         0.012  transfus_yes      RAND       LR    7        1.0   100
# 35         0.010  transfus_yes      RAND       LR    7        1.0  1000
# 17         0.010  transfus_yes      RAND       LR    7        1.0  1000
# 16         0.013  transfus_yes      RAND       LR    7        1.0  1000
# 15         0.013  transfus_yes      RAND       LR    7        1.0   100
# 14         0.012  transfus_yes      RAND       LR    7        1.0   100
# 36         0.010  transfus_yes      RAND       LR    7        1.0   100
# 37         0.013  transfus_yes      RAND       LR    7        1.0   100
# 11         0.009  transfus_yes      RAND       LR    7        1.0  1000
# 10         0.009  transfus_yes      RAND       LR    7        1.0  1000
# 38         0.013  transfus_yes      RAND       LR    7        1.0   100
# 8          0.008  transfus_yes      RAND       LR    7        1.0   100
# 7          0.009  transfus_yes      RAND       LR    7        1.0   100
# 39         0.013  transfus_yes      RAND       LR    7        1.0  1000
# 5          0.009  transfus_yes      RAND       LR    7        1.0  1000
# 4          0.009  transfus_yes      RAND       LR    7        1.0  1000
# 40         0.011  transfus_yes      RAND       LR    7        1.0  1000
# 2          0.008  transfus_yes      RAND       LR    7        1.0   100
# 33         0.013  transfus_yes      RAND       LR    7        1.0  1000
# 0          0.007  transfus_yes      RAND       LR    7        1.0   100
# 18         0.005  transfus_yes      RAND       LR    7        1.0   100
# 13         0.006  transfus_yes      RAND       LR    7        1.0  1000
# 12         0.005  transfus_yes      RAND       LR    7        1.0   100
# 9          0.003  transfus_yes      RAND       LR    7        1.0  1000
# 6          0.005  transfus_yes      RAND       LR    7        1.0   100
# 3          0.003  transfus_yes      RAND       LR    7        1.0  1000
# 21         0.009  transfus_yes      RAND       LR    7        1.0  1000
#
#    p_max_iter p_random_state   p_solver     TN     FP   FN    TP precision_2  \
# 41    1000000              7  liblinear  40513  13560  205  1346       0.090
# 25     100000              7  liblinear  40478  13595  206  1345       0.090
# 19        100              7  liblinear  40478  13595  206  1345       0.090
# 20       1000              7  liblinear  40478  13595  206  1345       0.090
# 1         100              7  liblinear  40478  13595  206  1345       0.090
# 22        100              7  liblinear  40513  13560  205  1346       0.090
# 23       1000              7  liblinear  40513  13560  205  1346       0.090
# 24      10000              7  liblinear  40478  13595  206  1345       0.090
# 26    1000000              7  liblinear  40478  13595  206  1345       0.090
# 34     100000              7  liblinear  40513  13560  205  1346       0.090
# 27      10000              7  liblinear  40513  13560  205  1346       0.090
# 28     100000              7  liblinear  40513  13560  205  1346       0.090
# 29    1000000              7  liblinear  40513  13560  205  1346       0.090
# 30      10000              7  liblinear  40478  13595  206  1345       0.090
# 31     100000              7  liblinear  40478  13595  206  1345       0.090
# 32    1000000              7  liblinear  40478  13595  206  1345       0.090
# 35    1000000              7  liblinear  40513  13560  205  1346       0.090
# 17       1000              7  liblinear  40513  13560  205  1346       0.090
# 16        100              7  liblinear  40513  13560  205  1346       0.090
# 15       1000              7  liblinear  40478  13595  206  1345       0.090
# 14        100              7  liblinear  40478  13595  206  1345       0.090
# 36      10000              7  liblinear  40478  13595  206  1345       0.090
# 37     100000              7  liblinear  40478  13595  206  1345       0.090
# 11       1000              7  liblinear  40513  13560  205  1346       0.090
# 10        100              7  liblinear  40513  13560  205  1346       0.090
# 38    1000000              7  liblinear  40478  13595  206  1345       0.090
# 8        1000              7  liblinear  40478  13595  206  1345       0.090
# 7         100              7  liblinear  40478  13595  206  1345       0.090
# 39      10000              7  liblinear  40513  13560  205  1346       0.090
# 5        1000              7  liblinear  40513  13560  205  1346       0.090
# 4         100              7  liblinear  40513  13560  205  1346       0.090
# 40     100000              7  liblinear  40513  13560  205  1346       0.090
# 2        1000              7  liblinear  40478  13595  206  1345       0.090
# 33      10000              7  liblinear  40513  13560  205  1346       0.090
# 0          10              7  liblinear  41404  12669  320  1231       0.089
# 18         10              7  liblinear  41404  12669  320  1231       0.089
# 13         10              7  liblinear  41404  12669  320  1231       0.089
# 12         10              7  liblinear  41404  12669  320  1231       0.089
# 9          10              7  liblinear  41404  12669  320  1231       0.089
# 6          10              7  liblinear  41404  12669  320  1231       0.089
# 3          10              7  liblinear  41404  12669  320  1231       0.089
# 21         10              7  liblinear  41404  12669  320  1231       0.089
#
#    recall_2   F1_2 precision_macro recall_macro F1_macro ROC_AUC PR_AUC  \
# 41    0.868  0.164           0.543        0.809    0.509   0.809  0.138
# 25    0.867  0.163           0.542        0.808    0.509   0.808  0.137
# 19    0.867  0.163           0.542        0.808    0.509   0.808  0.137
# 20    0.867  0.163           0.542        0.808    0.509   0.808  0.137
# 1     0.867  0.163           0.542        0.808    0.509   0.808  0.137
# 22    0.868  0.164           0.543        0.809    0.509   0.809  0.138
# 23    0.868  0.164           0.543        0.809    0.509   0.809  0.138
# 24    0.867  0.163           0.542        0.808    0.509   0.808  0.137
# 26    0.867  0.163           0.542        0.808    0.509   0.808  0.137
# 34    0.868  0.164           0.543        0.809    0.509   0.809  0.138
# 27    0.868  0.164           0.543        0.809    0.509   0.809  0.138
# 28    0.868  0.164           0.543        0.809    0.509   0.809  0.138
# 29    0.868  0.164           0.543        0.809    0.509   0.809  0.138
# 30    0.867  0.163           0.542        0.808    0.509   0.808  0.137
# 31    0.867  0.163           0.542        0.808    0.509   0.808  0.137
# 32    0.867  0.163           0.542        0.808    0.509   0.808  0.137
# 35    0.868  0.164           0.543        0.809    0.509   0.809  0.138
# 17    0.868  0.164           0.543        0.809    0.509   0.809  0.138
# 16    0.868  0.164           0.543        0.809    0.509   0.809  0.138
# 15    0.867  0.163           0.542        0.808    0.509   0.808  0.137
# 14    0.867  0.163           0.542        0.808    0.509   0.808  0.137
# 36    0.867  0.163           0.542        0.808    0.509   0.808  0.137
# 37    0.867  0.163           0.542        0.808    0.509   0.808  0.137
# 11    0.868  0.164           0.543        0.809    0.509   0.809  0.138
# 10    0.868  0.164           0.543        0.809    0.509   0.809  0.138
# 38    0.867  0.163           0.542        0.808    0.509   0.808  0.137
# 8     0.867  0.163           0.542        0.808    0.509   0.808  0.137
# 7     0.867  0.163           0.542        0.808    0.509   0.808  0.137
# 39    0.868  0.164           0.543        0.809    0.509   0.809  0.138
# 5     0.868  0.164           0.543        0.809    0.509   0.809  0.138
# 4     0.868  0.164           0.543        0.809    0.509   0.809  0.138
# 40    0.868  0.164           0.543        0.809    0.509   0.809  0.138
# 2     0.867  0.163           0.542        0.808    0.509   0.808  0.137
# 33    0.868  0.164           0.543        0.809    0.509   0.809  0.138
# 0     0.794  0.159           0.540        0.780    0.512   0.780  0.088
# 18    0.794  0.159           0.540        0.780    0.512   0.780  0.088
# 13    0.794  0.159           0.540        0.780    0.512   0.780  0.088
# 12    0.794  0.159           0.540        0.780    0.512   0.780  0.088
# 9     0.794  0.159           0.540        0.780    0.512   0.780  0.088
# 6     0.794  0.159           0.540        0.780    0.512   0.780  0.088
# 3     0.794  0.159           0.540        0.780    0.512   0.780  0.088
# 21    0.794  0.159           0.540        0.780    0.512   0.780  0.088
#
#       MCC  Combo
# 41  0.229  0.522
# 25  0.229  0.522
# 19  0.229  0.522
# 20  0.229  0.522
# 1   0.229  0.522
# 22  0.229  0.522
# 23  0.229  0.522
# 24  0.229  0.522
# 26  0.229  0.522
# 34  0.229  0.522
# 27  0.229  0.522
# 28  0.229  0.522
# 29  0.229  0.522
# 30  0.229  0.522
# 31  0.229  0.522
# 32  0.229  0.522
# 35  0.229  0.522
# 17  0.229  0.522
# 16  0.229  0.522
# 15  0.229  0.522
# 14  0.229  0.522
# 36  0.229  0.522
# 37  0.229  0.522
# 11  0.229  0.522
# 10  0.229  0.522
# 38  0.229  0.522
# 8   0.229  0.522
# 7   0.229  0.522
# 39  0.229  0.522
# 5   0.229  0.522
# 4   0.229  0.522
# 40  0.229  0.522
# 2   0.229  0.522
# 33  0.229  0.522
# 0   0.213  0.511
# 18  0.213  0.511
# 13  0.213  0.511
# 12  0.213  0.511
# 9   0.213  0.511
# 6   0.213  0.511
# 3   0.213  0.511
# 21  0.213  0.511

# %%
#results_T.to_csv('/MFMDatasets/MFM_bopf/src/multi_predict/NB/output/NBout.csv')
#results_T.to_csv('/MFMDatasets/MFM_bopf/src/multi_predict/LR/output/LRout.csv')
#results_T.to_csv('/MFMDatasets/MFM_bopf/src/multi_predict/RF/output/RFout.csv')
#results_T.to_csv('/MFMDatasets/MFM_bopf/src/multi_predict/SVC/output/SVCout.csv')
#results_T.to_csv('/MFMDatasets/MFM_bopf/src/multi_predict/LSVC/output/LSVCout.csv')
#results_T.to_csv('/MFMDatasets/MFM_bopf/src/multi_predict/MLP/output/MLPout.csv')
