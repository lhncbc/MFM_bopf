# %%
import pandas as pd
import os
import glob

pd.options.display.max_columns = None
pd.options.display.max_rows = None

#os.chdir('/MFMDatasets/MFM_bopf/src/multi_predict/oldMay/SVC/output')
#os.chdir('/slurm_storage/mbopf/projects/MFM_bopf/src/multi_predict/output')
#os.chdir('/slurm_storage/mbopf/projects/MFM_bopf/src/multi_predict/SVC/output')
#os.chdir('/MFMDatasets/MFM_bopf/src/multi_predict/LR/output')
#os.chdir('/MFMDatasets/MFM_bopf/src/multi_predict/LR/output/old')
#os.chdir('/MFMDatasets/MFM_bopf/src/multi_predict/RF/output')
#os.chdir('/slurm_storage/mbopf/projects/MFM_bopf/src/multi_predict/RF/output')
#os.chdir('/MFMDatasets/MFM_bopf/src/multi_predict/SVC/output')
#os.chdir('/MFMDatasets/MFM_bopf/src/multi_predict/LSVC/output')
#os.chdir('/MFMDatasets/MFM_bopf/src/multi_predict/MLP/output')
os.chdir('/slurm_storage/mbopf/projects/MFM_bopf/src/multi_predict/MLP/output')
#os.chdir('/MFMDatasets/MFM_bopf/src/multi_predict/NB/output')
results_df = pd.DataFrame()
#files = glob.glob("*-NB-*.csv")
#files = glob.glob("*-LR-*.csv")
#files = glob.glob("*-RF-*.csv")
#files = glob.glob("*-SVC-*.csv")
#files = glob.glob("*-LSVC-*.csv")
#files = glob.glob("*-MLP-*.csv")
files = glob.glob("transfus_yes*-MLP-*.csv")
#files = glob.glob("transfus_hyster*-MLP-*.csv")
#files = glob.glob("transfus_yes*-MLP-*.csv")
#files = glob.glob("transfus_yes*-MLP-*.csv")

# %%
files.sort()
for i in range(len(files)-1):
    if files[i][:-20] == files[i+1][:-20]:
        print(f'{files[i]}')
# Out:
# transfus_yes-1-RAND-MLP-relu_1e-05_[52,26,13,6]_0.001_500_7_adam-1-1.0-20201023_140150.csv
# transfus_yes-1-RAND-MLP-relu_1e-05_[64,32,16,8,4]_0.001_500_7_adam-1-1.0-20201023_140141.csv

# %%
#files.sort(key=os.path.getmtime) # Why???
files.sort()
prev_f = ""
for idx, f in enumerate(files):
    if prev_f[:-20] == f[:-20]:   #if the filenames only differ by timestamp
        print(f'{prev_f}')
        continue   #skip "duplicate"
        
    if results_df.empty:
        results_df = pd.read_csv(f, header=None, index_col=0, names=[idx])
    else:
        this_df = pd.read_csv(f, header=None, index_col=0, names=[idx])
        results_df = results_df.merge(this_df, left_index=True, right_index=True, how="right")
    prev_f = f
results_df
# Out:
# transfus_yes-1-RAND-MLP-relu_1e-05_[52,26,13,6]_0.001_500_7_adam-1-1.0-20201023_140150.csv
# transfus_yes-1-RAND-MLP-relu_1e-05_[64,32,16,8,4]_0.001_500_7_adam-1-1.0-20201023_140141.csv
#                                   0                   1                2    \
# CLF_time(min)                   0.101               0.162            0.094
# target                   transfus_yes        transfus_yes     transfus_yes
# under_alg                     Hostype             Hostype          Hostype
# pred_alg                          MLP                 MLP              MLP
# seed                                1                   1                1
# samp_strat                        1.0                 1.0              1.0
# sample_tts                          1                   1                1
# p_activation                     relu                relu             relu
# p_alpha                         0.001               0.001              0.1
# ...

# %%
results_T = results_df.T
#results_T[results_T['p_kernel']=='poly'].sort_values(by=['p_kernel','Combo'], ascending=False)
#results_T.sort_values(by=['Combo'], ascending=False, inplace=True)
results_T.sort_values(by=['ROC_AUC'], ascending=False, inplace=True)
#results_T
small = results_T[['target','under_alg','p_activation','p_alpha','p_hidden_layer_sizes','p_random_state','p_solver','ROC_AUC','MCC']]
#small['p_alpha'] = pd.to_numeric(small['p_alpha'])
#small.sort_values(by=['p_alpha'], inplace=True)
small.sort_values(by=['ROC_AUC'], ascending=False, inplace=True)
#small.sort_values(by=['under_alg','p_alpha'], ascending=False, inplace=True)
small
# Out:
# /opt/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#            target    under_alg p_activation p_alpha p_hidden_layer_sizes  \
# 17   transfus_yes         RAND         relu   0.001      [52, 26, 13, 6]
# 21   transfus_yes         RAND         relu   0.001      [52, 26, 13, 6]
# 111  transfus_yes         RAND         relu   1e-05   [64, 32, 16, 8, 4]
# 72   transfus_yes         RAND         relu     0.3      [52, 26, 13, 6]
# 40   transfus_yes         RAND         relu    0.05   [64, 32, 16, 8, 4]
# 91   transfus_yes         RAND         relu     1.5      [52, 26, 13, 6]
# 112  transfus_yes         RAND         relu   1e-05   [64, 32, 16, 8, 4]
# ...

# %%
#results_T.to_csv('/MFMDatasets/MFM_bopf/src/multi_predict/NB/output/NBout.csv')
#results_T.to_csv('/MFMDatasets/MFM_bopf/src/multi_predict/NB/output/NBout-seed.csv')
#results_T.to_csv('/MFMDatasets/MFM_bopf/src/multi_predict/LR/output/LRout.csv')
#results_T.to_csv('/MFMDatasets/MFM_bopf/src/multi_predict/RF/output/RFout.csv')
#results_T.to_csv('/MFMDatasets/MFM_bopf/src/multi_predict/SVC/output/SVCout_2020-09-23.csv')
#results_T.to_csv('/MFMDatasets/MFM_bopf/src/multi_predict/LSVC/output/LSVCout.csv')
#results_T.to_csv('/MFMDatasets/MFM_bopf/src/multi_predict/MLP/output/MLPout.csv')
