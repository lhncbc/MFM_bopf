# %%
import numpy as np
import pandas as pd
import os, glob
pd.options.display.float_format = '{:0.4f}'.format

# %%
df = pd.read_csv('/MFMDatasets/MFM_bopf/data/csl/CSL_he_PI_comp.csv', header=0, index_col=0)
df

# %%
df
# Out:
#           high_EBL  Accrete  AdmBishop  Admcervpos  Admconsistency  \
# MomID
# 41-00003         0        0          6           3               2
# 41-00004         0        0          5           3               2
# 41-00006         0        0         11           1               3
# 41-00007         0        0          4           2               2
# 41-00008         0        0          6           3               2
# ...            ...      ...        ...         ...             ...
# 52-07247         0        0          8           8               8
# 52-07248         0        0          8           8               8
# 52-07249         1        0          8           8               8
# 52-07250         0        0          8           8               8
# 52-07251         0        0          8           8               8
#
#           Admcontract  AdmDBP  Admefface  Admpresent   AdmSBP  ...  \
# MomID                                                          ...
# ...

# %%
df['Delmode'].value_counts()
# Out:
# 1    85364
# 4    25818
# 5    15989
# 2     6019
# 3     3297
# Name: Delmode, dtype: int64

# %%
chiData = df[['high_EBL', 'new_high_Age', 'new_high_BMI', 'Delmode', 'HxnumCS', 'CPD', 'Hyp_ace']].copy()
chiData
# Out:
#           high_EBL  new_high_Age  new_high_BMI  Delmode  HxnumCS  CPD  Hyp_ace
# MomID
# 41-00003         0             1             1        1        0    0        0
# 41-00004         0             1             1        1        0    0        0
# 41-00006         0             1             1        1        0    0        0
# 41-00007         0             2             1        4        0    0        0
# 41-00008         0             1             0        1        0    0        0
# ...            ...           ...           ...      ...      ...  ...      ...
# 52-07247         0             0             1        2        0    0        0
# 52-07248         0             1             1        3        1    0        0
# 52-07249         1             1             1        5        1    0        0
# 52-07250         0             0             1        1        0    0        0
# 52-07251         0             2             1        1        0    0        0
#
# ...

# %%
# Delmode as binary
chiData.loc[(chiData['Delmode'] < 4), 'Delmode'] = 0
chiData.loc[(chiData['Delmode'] >= 4), 'Delmode'] = 1
chiData
# Out:
#           high_EBL  new_high_Age  new_high_BMI  Delmode  HxnumCS  CPD  Hyp_ace
# MomID
# 41-00003         0             1             1        0        0    0        0
# 41-00004         0             1             1        0        0    0        0
# 41-00006         0             1             1        0        0    0        0
# 41-00007         0             2             1        1        0    0        0
# 41-00008         0             1             0        0        0    0        0
# ...            ...           ...           ...      ...      ...  ...      ...
# 52-07247         0             0             1        0        0    0        0
# 52-07248         0             1             1        0        1    0        0
# 52-07249         1             1             1        1        1    0        0
# 52-07250         0             0             1        0        0    0        0
# 52-07251         0             2             1        0        0    0        0
#
# ...

# %%
X = chiData.drop('high_EBL', axis=1)
y = chiData['high_EBL']
X.shape, y.shape
# Out:
# ((136487, 6), (136487,))

# %%
from sklearn.feature_selection import chi2
np.set_printoptions(precision=2, suppress=True)
chi_vals, p_vals = chi2(X, y)
chi_vals
# Out:
# array([  20.93,   72.23, 7289.17, 1439.96,    3.64,    0.66])

# %%
# Before making Delmode binary (1-5)
#from sklearn.feature_selection import chi2
#chi_vals, p_vals = chi2(X, y)
#chi_vals

# Results (new_high_Age, new_high_BMI, Delmode)
#array([   20.93119155,    72.23475626, 10918.24418593])
#array([4.76079165e-06, 1.91060887e-17, 0.00000000e+00]) <- pvalues

# %% [markdown]
# ### I think something is wrong. CPD has a Cramer value of 0.00098 so shouldn't have a p-value of 0.056. This is basically saying that almost all of our variables are dependent.

# %%
np.set_printoptions(precision=4, suppress=True)
p_vals
# Out:
# array([0.    , 0.    , 0.    , 0.    , 0.0562, 0.4162])

# %%
chi2(chiData[['CPD']], y)
# Out:
# (array([3.645]), array([0.0562]))
