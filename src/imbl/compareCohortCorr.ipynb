# %%
import numpy as np
import pandas as pd
import os, glob
pd.options.display.float_format = '{:0.4f}'.format

# %%
# @TODO: Change hard-coded paths to wildcards
for f in glob.glob('/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/corr-transfus_yes-Hostype-1.0-Theil*.csv'):
    ty_host_T = pd.read_csv(f, index_col=0)
for f in glob.glob('/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/corr-transfus_yes-Insurance-1.0-Theil*.csv'):
    ty_Ins_T = pd.read_csv(f, index_col=0)
for f in glob.glob('/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/corr-transfus_yes-high_Age-1.0-Theil*.csv'):
    ty_age_T = pd.read_csv(f, index_col=0)
for f in glob.glob('/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/corr-transfus_yes-momrace_new-1.0-Theil*.csv'):
    ty_momrace_T = pd.read_csv(f, index_col=0)
for f in glob.glob('/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/corr-transfus_yes-RAND-1.0-Theil*.csv'):
    ty_RAND_T = pd.read_csv(f, index_col=0)
for f in glob.glob('/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/corr-transfus_yes-Hostype-1.0-Cramer*.csv'):
    ty_host_C = pd.read_csv(f, index_col=0)
for f in glob.glob('/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/corr-transfus_yes-Insurance-1.0-Cramer*.csv'):
    ty_Ins_C = pd.read_csv(f, index_col=0)
for f in glob.glob('/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/corr-transfus_yes-high_Age-1.0-Cramer*.csv'):
    ty_age_C = pd.read_csv(f, index_col=0)
for f in glob.glob('/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/corr-transfus_yes-momrace_new-1.0-Cramer*.csv'):
    ty_momrace_C = pd.read_csv(f, index_col=0)
for f in glob.glob('/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/corr-transfus_yes-RAND-1.0-Cramer*.csv'):
    ty_RAND_C = pd.read_csv(f, index_col=0)

# %%
ty_host_T.head()
# Out:
#                 corr0  corr1  corr2  corr3  corr4  corr5  corr6  corr7  corr8  \
# transfus_yes   1.0000 1.0000 1.0000 1.0000 1.0000 1.0000 1.0000 1.0000 1.0000
# Inoxy_incrdose 0.1201 0.1164 0.1121 0.1125 0.1150 0.1080 0.1120 0.1083 0.1084
# Admcontract    0.0898 0.0912 0.0857 0.0896 0.0858 0.0835 0.0851 0.0809 0.0838
# HosEpiNurse    0.0878 0.0828 0.0811 0.0826 0.0801 0.0792 0.0797 0.0767 0.0807
# BESTGA         0.0801 0.0740 0.0782 0.0819 0.0844 0.0795 0.0764 0.0735 0.0753
#
#                 corr9  mean_corr
# transfus_yes   1.0000     1.0000
# Inoxy_incrdose 0.1112     0.1124
# Admcontract    0.0858     0.0861
# HosEpiNurse    0.0797     0.0811
# BESTGA         0.0753     0.0779

# %%
combined = pd.DataFrame(ty_host_T['mean_corr']).rename(columns={'mean_corr':"Host_T"})
combined_C = pd.DataFrame(ty_host_C['mean_corr']).rename(columns={'mean_corr':"Host_C"})
combined
# Out:
#                 Host_T
# transfus_yes    1.0000
# Inoxy_incrdose  0.1124
# Admcontract     0.0861
# HosEpiNurse     0.0811
# BESTGA          0.0779
# ...                ...
# CS_Other        0.0000
# Antechorio      0.0000
# TTTwin          0.0000
# Hyp_alpha       0.0000
# R_preg          0.0000
#
# [232 rows x 1 columns]

# %%
combined_C
# Out:
#                 Host_C
# transfus_yes    0.9998
# Inoxy_incrdose  0.3727
# Admcontract     0.3242
# HosEpiNurse     0.3176
# Intratocolytix  0.2957
# ...                ...
# AB_flagyl       0.0000
# AB_clind        0.0000
# PPROM_new       0.0000
# version9        0.0000
# R_preg          0.0000
#
# [232 rows x 1 columns]

# %%
next_df = pd.DataFrame(ty_Ins_T['mean_corr'])
combined = pd.merge(combined, next_df, left_index=True, right_index=True)
combined.rename(columns={'mean_corr':"Ins_T"}, inplace=True)
combined
# Out:
#                 Host_T  Ins_T
# transfus_yes    1.0000 1.0000
# Inoxy_incrdose  0.1124 0.1894
# Admcontract     0.0861 0.1324
# HosEpiNurse     0.0811 0.1048
# BESTGA          0.0779 0.1149
# ...                ...    ...
# CS_Other        0.0000 0.0000
# Antechorio      0.0000 0.0001
# TTTwin          0.0000 0.0000
# Hyp_alpha       0.0000 0.0000
# R_preg          0.0000 0.0000
#
# [232 rows x 2 columns]

# %%
next_df = pd.DataFrame(ty_Ins_C['mean_corr'])
combined_C = pd.merge(combined_C, next_df, left_index=True, right_index=True)
combined_C.rename(columns={'mean_corr':"Ins_C"}, inplace=True)
combined_C
# Out:
#                 Host_C  Ins_C
# transfus_yes    0.9998 0.9998
# Inoxy_incrdose  0.3727 0.4879
# Admcontract     0.3242 0.4077
# HosEpiNurse     0.3176 0.3629
# Intratocolytix  0.2957 0.4376
# ...                ...    ...
# AB_flagyl       0.0000 0.0006
# AB_clind        0.0000 0.0018
# PPROM_new       0.0000 0.0059
# version9        0.0000 0.0007
# R_preg          0.0000 0.0000
#
# [232 rows x 2 columns]

# %%
next_df = pd.DataFrame(ty_age_T['mean_corr'])
combined = pd.merge(combined, next_df, left_index=True, right_index=True)
combined.rename(columns={'mean_corr':"Age_T"}, inplace=True)
combined
# Out:
#                 Host_T  Ins_T  Age_T
# transfus_yes    1.0000 1.0000 1.0000
# Inoxy_incrdose  0.1124 0.1894 0.1861
# Admcontract     0.0861 0.1324 0.1519
# HosEpiNurse     0.0811 0.1048 0.1178
# BESTGA          0.0779 0.1149 0.1255
# ...                ...    ...    ...
# CS_Other        0.0000 0.0000 0.0001
# Antechorio      0.0000 0.0001 0.0001
# TTTwin          0.0000 0.0000 0.0000
# Hyp_alpha       0.0000 0.0000 0.0000
# R_preg          0.0000 0.0000 0.0000
#
# [232 rows x 3 columns]

# %%
next_df = pd.DataFrame(ty_age_C['mean_corr'])
combined_C = pd.merge(combined_C, next_df, left_index=True, right_index=True)
combined_C.rename(columns={'mean_corr':"Age_C"}, inplace=True)
combined_C
# Out:
#                 Host_C  Ins_C  Age_C
# transfus_yes    0.9998 0.9998 0.9998
# Inoxy_incrdose  0.3727 0.4879 0.4854
# Admcontract     0.3242 0.4077 0.4385
# HosEpiNurse     0.3176 0.3629 0.3853
# Intratocolytix  0.2957 0.4376 0.4808
# ...                ...    ...    ...
# AB_flagyl       0.0000 0.0006 0.0006
# AB_clind        0.0000 0.0018 0.0072
# PPROM_new       0.0000 0.0059 0.0120
# version9        0.0000 0.0007 0.0054
# R_preg          0.0000 0.0000 0.0000
#
# [232 rows x 3 columns]

# %%
next_df = pd.DataFrame(ty_momrace_T['mean_corr'])
combined = pd.merge(combined, next_df, left_index=True, right_index=True)
combined.rename(columns={'mean_corr':"race_T"}, inplace=True)
combined.head(20)
# Out:
#                 Host_T  Ins_T  Age_T  race_T
# transfus_yes    1.0000 1.0000 1.0000  1.0000
# Inoxy_incrdose  0.1124 0.1894 0.1861  0.1506
# Admcontract     0.0861 0.1324 0.1519  0.1256
# HosEpiNurse     0.0811 0.1048 0.1178  0.0997
# BESTGA          0.0779 0.1149 0.1255  0.1078
# Intratocolytix  0.0686 0.1472 0.1779  0.1346
# Education       0.0633 0.1379 0.1331  0.1214
# DMControl       0.0585 0.0958 0.1207  0.0935
# HxnumCS         0.0468 0.0540 0.0509  0.0509
# HospElectCS     0.0450 0.1269 0.1232  0.0829
# ROMmeth         0.0449 0.0441 0.0384  0.0411
# AdmSBP          0.0346 0.0585 0.0727  0.0747
# Admpresent      0.0313 0.0450 0.0477  0.0421
# Dilat_lst       0.0304 0.0423 0.0470  0.0437
# AdmDBP          0.0280 0.0485 0.0605  0.0625
# Episiotomy      0.0264 0.0370 0.0384  0.0309
# Augment         0.0246 0.0554 0.0582  0.0480
# Admreason       0.0245 0.0298 0.0208  0.0190
# HospElectInd    0.0200 0.0558 0.0472  0.0395
# AdmBishop       0.0194 0.0591 0.0785  0.0550

# %%
next_df = pd.DataFrame(ty_momrace_C['mean_corr'])
combined_C = pd.merge(combined_C, next_df, left_index=True, right_index=True)
combined_C.rename(columns={'mean_corr':"race_C"}, inplace=True)
combined_C.head(20)
# Out:
#                 Host_C  Ins_C  Age_C  race_C
# transfus_yes    0.9998 0.9998 0.9998  0.9998
# Inoxy_incrdose  0.3727 0.4879 0.4854  0.4349
# Admcontract     0.3242 0.4077 0.4385  0.3999
# HosEpiNurse     0.3176 0.3629 0.3853  0.3507
# Intratocolytix  0.2957 0.4376 0.4808  0.4223
# Education       0.2912 0.4266 0.4204  0.4033
# DMControl       0.2786 0.3548 0.4012  0.3554
# BESTGA          0.2634 0.3453 0.3657  0.3284
# HospElectCS     0.2463 0.4090 0.4039  0.3337
# HxnumCS         0.2328 0.2502 0.2432  0.2362
# ROMmeth         0.2215 0.2216 0.2075  0.2121
# Admpresent      0.2027 0.2441 0.2508  0.2360
# Dilat_lst       0.1920 0.2245 0.2352  0.2285
# Admreason       0.1800 0.1992 0.1648  0.1618
# Augment         0.1794 0.2644 0.2718  0.2497
# Episiotomy      0.1788 0.2154 0.2197  0.1976
# AdmSBP          0.1766 0.2510 0.2824  0.2849
# AdmDBP          0.1676 0.2344 0.2639  0.2652
# AdmBishop       0.1601 0.2817 0.3222  0.2720
# HospElectInd    0.1575 0.2596 0.2412  0.2173

# %%
next_df = pd.DataFrame(ty_RAND_T['mean_corr'])
combined = pd.merge(combined, next_df, left_index=True, right_index=True)
combined.rename(columns={'mean_corr':"RAND_T"}, inplace=True)
combined.head(20)
# Out:
#                 Host_T  Ins_T  Age_T  race_T  RAND_T
# transfus_yes    1.0000 1.0000 1.0000  1.0000  1.0000
# Inoxy_incrdose  0.1124 0.1894 0.1861  0.1506  0.1873
# Admcontract     0.0861 0.1324 0.1519  0.1256  0.1526
# HosEpiNurse     0.0811 0.1048 0.1178  0.0997  0.1193
# BESTGA          0.0779 0.1149 0.1255  0.1078  0.1255
# Intratocolytix  0.0686 0.1472 0.1779  0.1346  0.1790
# Education       0.0633 0.1379 0.1331  0.1214  0.1350
# DMControl       0.0585 0.0958 0.1207  0.0935  0.1213
# HxnumCS         0.0468 0.0540 0.0509  0.0509  0.0512
# HospElectCS     0.0450 0.1269 0.1232  0.0829  0.1248
# ROMmeth         0.0449 0.0441 0.0384  0.0411  0.0379
# AdmSBP          0.0346 0.0585 0.0727  0.0747  0.0706
# Admpresent      0.0313 0.0450 0.0477  0.0421  0.0474
# Dilat_lst       0.0304 0.0423 0.0470  0.0437  0.0480
# AdmDBP          0.0280 0.0485 0.0605  0.0625  0.0595
# Episiotomy      0.0264 0.0370 0.0384  0.0309  0.0390
# Augment         0.0246 0.0554 0.0582  0.0480  0.0566
# ...

# %%
next_df = pd.DataFrame(ty_RAND_C['mean_corr'])
combined_C = pd.merge(combined_C, next_df, left_index=True, right_index=True)
combined_C.rename(columns={'mean_corr':"RAND_C"}, inplace=True)
combined_C.head(20)
# Out:
#                 Host_C  Ins_C  Age_C  race_C  RAND_C
# transfus_yes    0.9998 0.9998 0.9998  0.9998  0.9998
# Inoxy_incrdose  0.3727 0.4879 0.4854  0.4349  0.4913
# Admcontract     0.3242 0.4077 0.4385  0.3999  0.4408
# HosEpiNurse     0.3176 0.3629 0.3853  0.3507  0.3857
# Intratocolytix  0.2957 0.4376 0.4808  0.4223  0.4851
# Education       0.2912 0.4266 0.4204  0.4033  0.4267
# DMControl       0.2786 0.3548 0.4012  0.3554  0.4042
# BESTGA          0.2634 0.3453 0.3657  0.3284  0.3660
# HospElectCS     0.2463 0.4090 0.4039  0.3337  0.4108
# HxnumCS         0.2328 0.2502 0.2432  0.2362  0.2430
# ROMmeth         0.2215 0.2216 0.2075  0.2121  0.2091
# Admpresent      0.2027 0.2441 0.2508  0.2360  0.2576
# Dilat_lst       0.1920 0.2245 0.2352  0.2285  0.2395
# Admreason       0.1800 0.1992 0.1648  0.1618  0.1685
# Augment         0.1794 0.2644 0.2718  0.2497  0.2749
# Episiotomy      0.1788 0.2154 0.2197  0.1976  0.2230
# AdmSBP          0.1766 0.2510 0.2824  0.2849  0.2804
# ...

# %%
# Add column for the average rank and sort by it
combined['mean_corr'] = combined.apply(np.average, axis=1)
combined.sort_values(by='mean_corr', ascending=False, inplace=True)
combined.head(20)
# Out:
#                 Host_T  Ins_T  Age_T  race_T  RAND_T  mean_corr
# transfus_yes    1.0000 1.0000 1.0000  1.0000  1.0000     1.0000
# Inoxy_incrdose  0.1124 0.1894 0.1861  0.1506  0.1873     0.1652
# Intratocolytix  0.0686 0.1472 0.1779  0.1346  0.1790     0.1415
# Admcontract     0.0861 0.1324 0.1519  0.1256  0.1526     0.1297
# Education       0.0633 0.1379 0.1331  0.1214  0.1350     0.1181
# BESTGA          0.0779 0.1149 0.1255  0.1078  0.1255     0.1103
# HosEpiNurse     0.0811 0.1048 0.1178  0.0997  0.1193     0.1045
# HospElectCS     0.0450 0.1269 0.1232  0.0829  0.1248     0.1006
# DMControl       0.0585 0.0958 0.1207  0.0935  0.1213     0.0980
# AdmSBP          0.0346 0.0585 0.0727  0.0747  0.0706     0.0622
# Hostype         0.0001 0.0584 0.0922  0.0596  0.0940     0.0609
# AdmBishop       0.0194 0.0591 0.0785  0.0550  0.0809     0.0586
# AdmDBP          0.0280 0.0485 0.0605  0.0625  0.0595     0.0518
# HxnumCS         0.0468 0.0540 0.0509  0.0509  0.0512     0.0508
# ...

# %%
# Add column for the average rank and sort by it
combined_C['mean_corr'] = combined_C.apply(np.average, axis=1)
combined_C.sort_values(by='mean_corr', ascending=False, inplace=True)
combined_C.head(20)
# Out:
#                 Host_C  Ins_C  Age_C  race_C  RAND_C  mean_corr
# transfus_yes    0.9998 0.9998 0.9998  0.9998  0.9998     0.9998
# Inoxy_incrdose  0.3727 0.4879 0.4854  0.4349  0.4913     0.4544
# Intratocolytix  0.2957 0.4376 0.4808  0.4223  0.4851     0.4243
# Admcontract     0.3242 0.4077 0.4385  0.3999  0.4408     0.4022
# Education       0.2912 0.4266 0.4204  0.4033  0.4267     0.3936
# HospElectCS     0.2463 0.4090 0.4039  0.3337  0.4108     0.3608
# HosEpiNurse     0.3176 0.3629 0.3853  0.3507  0.3857     0.3604
# DMControl       0.2786 0.3548 0.4012  0.3554  0.4042     0.3588
# BESTGA          0.2634 0.3453 0.3657  0.3284  0.3660     0.3338
# AdmBishop       0.1601 0.2817 0.3222  0.2720  0.3258     0.2724
# AdmSBP          0.1766 0.2510 0.2824  0.2849  0.2804     0.2550
# Hostype         0.0020 0.2841 0.3505  0.2830  0.3499     0.2539
# Augment         0.1794 0.2644 0.2718  0.2497  0.2749     0.2481
# Delfetalpos     0.1422 0.2455 0.2894  0.2469  0.2877     0.2423
# ...

# %%
# Prevent accidental overwrite by checking if exists; comment out "if" to overwrite
filename = '/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/cohort_corr_summary-transfus_yes-Theil.csv'
if not os.path.exists(filename):
    combined.to_csv(filename)

# %%
filename = '/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/cohort_corr_summary-transfus_yes-Cramer.csv'
if not os.path.exists(filename):
    combined.to_csv(filename)
