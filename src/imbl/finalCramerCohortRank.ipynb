# %%
import numpy as np
import pandas as pd
import os, glob
pd.options.display.float_format = '{:0.2f}'.format

# %%
# @TODO: Change hard-coded paths to wildcards
#dataset = 'transfus_yes'
dataset = 'trans_loss'
#dataset = 'transfus_all'
for f in glob.glob('/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/rank-' + dataset + '-Hostype-1.0-Cramer*.csv'):
    ty_host_C = pd.read_csv(f, index_col=0)
for f in glob.glob('/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/rank-' + dataset + '-Insurance-1.0-Cramer*.csv'):
    ty_Ins_C = pd.read_csv(f, index_col=0)
for f in glob.glob('/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/rank-' + dataset + '-high_Age-1.0-Cramer*.csv'):
    ty_age_C = pd.read_csv(f, index_col=0)
for f in glob.glob('/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/rank-' + dataset + '-momrace_new-1.0-Cramer*.csv'):
    ty_momrace_C = pd.read_csv(f, index_col=0)
for f in glob.glob('/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/rank-' + dataset + '-RAND-1.0-Cramer*.csv'):
    ty_RAND_C = pd.read_csv(f, index_col=0)

# %%
combined = pd.DataFrame(ty_host_C['mean_rank'].rank().astype('int')).rename(columns={'mean_rank':"Host_C"})
combined.head(20)
# Out:
#                 Host_C
# trans_loss           1
# Delmode              2
# delivery             3
# Sitenum              4
# high_MomLOS          5
# HxnumCS              6
# TrialLabor           7
# ROMmeth              8
# Dilat_lst            9
# Inoxy_incrdose      10
# prelaborCD          11
# Analgesia           12
# Insurance           13
# Admcontract         14
# Lac_Min             15
# BESTGA              16
# Admpresent          17
# uscar               18
# CS_UScar            19
# CS_FTP              20

# %%
next_df = pd.DataFrame(ty_Ins_C['mean_rank'].rank().astype('int'))
combined = pd.merge(combined, next_df, left_index=True, right_index=True)
combined.rename(columns={'mean_rank':"Ins_C"}, inplace=True)
combined.head(20)
# Out:
#                 Host_C  Ins_C
# trans_loss           1      1
# Delmode              2      2
# delivery             3      3
# Sitenum              4      4
# high_MomLOS          5      5
# HxnumCS              6      6
# TrialLabor           7      9
# ROMmeth              8      7
# Dilat_lst            9      8
# Inoxy_incrdose      10     10
# prelaborCD          11     12
# Analgesia           12     15
# Insurance           13    234
# Admcontract         14     11
# Lac_Min             15     16
# BESTGA              16     14
# Admpresent          17     12
# uscar               18     18
# CS_UScar            19     19
# CS_FTP              20     20

# %%
next_df = pd.DataFrame(ty_age_C['mean_rank'].rank().astype('int'))
combined = pd.merge(combined, next_df, left_index=True, right_index=True)
combined.rename(columns={'mean_rank':"Age_C"}, inplace=True)
combined.head(20)
# Out:
#                 Host_C  Ins_C  Age_C
# trans_loss           1      1      1
# Delmode              2      2      2
# delivery             3      3      3
# Sitenum              4      4      4
# high_MomLOS          5      5      5
# HxnumCS              6      6      6
# TrialLabor           7      9      9
# ROMmeth              8      7      8
# Dilat_lst            9      8      7
# Inoxy_incrdose      10     10     10
# prelaborCD          11     12     17
# Analgesia           12     15     15
# Insurance           13    234     11
# Admcontract         14     11     12
# Lac_Min             15     16     17
# BESTGA              16     14     13
# Admpresent          17     12     14
# uscar               18     18     21
# CS_UScar            19     19     23
# CS_FTP              20     20     24

# %%
next_df = pd.DataFrame(ty_momrace_C['mean_rank'].rank().astype('int'))
combined = pd.merge(combined, next_df, left_index=True, right_index=True)
combined.rename(columns={'mean_rank':"race_C"}, inplace=True)
combined.head(20)
# Out:
#                 Host_C  Ins_C  Age_C  race_C
# trans_loss           1      1      1       1
# Delmode              2      2      2       2
# delivery             3      3      3       3
# Sitenum              4      4      4       4
# high_MomLOS          5      5      5       5
# HxnumCS              6      6      6       6
# TrialLabor           7      9      9       8
# ROMmeth              8      7      8       9
# Dilat_lst            9      8      7       7
# Inoxy_incrdose      10     10     10      11
# prelaborCD          11     12     17      13
# Analgesia           12     15     15      18
# Insurance           13    234     11      12
# Admcontract         14     11     12      10
# Lac_Min             15     16     17      17
# BESTGA              16     14     13      16
# Admpresent          17     12     14      14
# uscar               18     18     21      20
# CS_UScar            19     19     23      21
# CS_FTP              20     20     24      22

# %%
next_df = pd.DataFrame(ty_RAND_C['mean_rank'].rank().astype('int'))
combined = pd.merge(combined, next_df, left_index=True, right_index=True)
combined.rename(columns={'mean_rank':"RAND_C"}, inplace=True)
combined.head(30)
# Out:
#                 Host_C  Ins_C  Age_C  race_C  RAND_C
# trans_loss           1      1      1       1       1
# Delmode              2      2      2       2       2
# delivery             3      3      3       3       3
# Sitenum              4      4      4       4       4
# high_MomLOS          5      5      5       5       5
# HxnumCS              6      6      6       6       6
# TrialLabor           7      9      9       8       8
# ROMmeth              8      7      8       9       8
# Dilat_lst            9      8      7       7       7
# Inoxy_incrdose      10     10     10      11      10
# prelaborCD          11     12     17      13      16
# Analgesia           12     15     15      18      15
# Insurance           13    234     11      12      11
# Admcontract         14     11     12      10      12
# Lac_Min             15     16     17      17      18
# BESTGA              16     14     13      16      13
# Admpresent          17     12     14      14      14
# uscar               18     18     21      20      21
# CS_UScar            19     19     23      21      24
# CS_FTP              20     20     24      22      23
# Hxcsection          21     22     27      23      26
# Admefface           22     31     29      28      30
# AdmSBP              23     23     16      15      17
# Lac_Unkn            24     42     43      43      46
# AdmDBP              25     24     19      19      19
# GAmethod            26     21     28      27      28
# CS_NRFHT            27     30     35      31      37
# HosEpiNurse         28     25     20      25      20
# Hxanemia            29     32     34      32      33
# Postbleed           30     27     31      28      31

# %%
# Remove transfus_yes, Sitenum, Hostype, Insurance, high_Age and momrace_new from DataFrame
#combined.drop(['transfus_yes','Sitenum', 'Hostype', 'Insurance', 'high_Age', 'momrace_new'], inplace=True)
combined.drop(['trans_loss','Sitenum', 'Hostype', 'Insurance', 'high_Age', 'momrace_new'], inplace=True)
#combined.drop(['transfus_all','Sitenum', 'Hostype', 'Insurance', 'high_Age', 'momrace_new'], inplace=True)

# %%
# Add column for the average rank and sort by it
combined['mean_rank'] = combined.apply(np.average, axis=1).rank()
combined.sort_values(by='mean_rank', ascending=True, inplace=True)
combined.head(50)
# Out:
#                   Host_C  Ins_C  Age_C  race_C  RAND_C  mean_rank
# Delmode                2      2      2       2       2       1.00
# delivery               3      3      3       3       3       2.00
# high_MomLOS            5      5      5       5       5       3.00
# HxnumCS                6      6      6       6       6       4.00
# Dilat_lst              9      8      7       7       7       5.00
# ROMmeth                8      7      8       9       8       6.00
# TrialLabor             7      9      9       8       8       7.00
# Inoxy_incrdose        10     10     10      11      10       8.00
# Admcontract           14     11     12      10      12       9.00
# prelaborCD            11     12     17      13      16      10.00
# Admpresent            17     12     14      14      14      11.00
# BESTGA                16     14     13      16      13      12.00
# Analgesia             12     15     15      18      15      13.00
# Lac_Min               15     16     17      17      18      14.00
# AdmSBP                23     23     16      15      17      15.00
# uscar                 18     18     21      20      21      16.00
# AdmDBP                25     24     19      19      19      17.50
# CS_UScar              19     19     23      21      24      17.50
# CS_FTP                20     20     24      22      23      19.00
# HosEpiNurse           28     25     20      25      20      20.00
# Hxcsection            21     22     27      23      26      21.00
# GAmethod              26     21     28      27      28      22.00
# Education             42     17     26      24      22      23.00
# Admefface             22     31     29      28      30      24.00
# DMControl             36     37     22      26      24      25.00
# Postbleed             30     27     31      28      31      26.00
# Episiotomy            31     28     32      33      32      27.00
# CS_NRFHT              27     30     35      31      37      28.50
# Hxanemia              29     32     34      32      33      28.50
# Intratocolytix        47     36     25      30      27      30.00
# Postfever             32     35     37      35      38      31.00
# Presentdel            34     33     40      36      41      32.00
# ga                    33     39     42      41      42      33.00
# Lac_Unkn              24     42     43      43      46      34.00
# abruption             38     38     41      42      40      35.00
# Ind_Unkn              46     58     33      34      34      36.00
# Augment               61     29     39      38      39      37.00
# breech                39     41     44      40      44      38.00
# previa9               40     39     46      44      45      39.00
# HospElectCS           72     26     38      46      36      40.00
# spontlabor            37     34     54      51      54      41.00
# previa_chart          44     44     47      48      48      42.00
# vertex                43     45     51      45      49      43.50
# AdmBishop             76     47     36      39      35      43.50
# Anteanemia            52     49     45      49      43      45.00
# IntraMgSO             45     51     48      53      51      47.00
# Anteprevia            48     46     50      52      52      47.00
# Intrafetdistress      40     53     52      50      53      47.00
# Lac_None              64     43     49      47      47      49.00
# CS_Pprevia            50     50     55      55      57      50.00

# %%
# NOTE - saving this in /MFMDatasets instead of /slurm_storage
#filename = '/MFMDatasets/MFM_bopf/data/csl/Final_cohort_rank-transfus_yes-Cramer.csv'
filename = '/MFMDatasets/MFM_bopf/data/csl/Final_cohort_rank-trans_loss-Cramer.csv'
#filename = '/MFMDatasets/MFM_bopf/data/csl/Final_cohort_rank-transfus_all-Cramer.csv'
if not os.path.exists(filename):
    combined.to_csv(filename)
