# %%
import numpy as np
import pandas as pd
import os, glob
pd.options.display.float_format = '{:0.4f}'.format

# %%
#for f in glob.glob('/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/corr-transfus_yes-Hostype-1.0-Theil*.csv'):
#    corr_T = pd.read_csv(f, index_col=0)
#for f in glob.glob('/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/corr-transfus_yes-Hostype-1.0-Cramer*.csv'):
#    corr_C = pd.read_csv(f, index_col=0)
#for f in glob.glob('/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/rank-transfus_yes-Hostype-1.0-Theil*.csv'):
#    rank_T = pd.read_csv(f, index_col=0)
#for f in glob.glob('/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/rank-transfus_yes-Hostype-1.0-Cramer*.csv'):
#    rank_C = pd.read_csv(f, index_col=0)

for f in glob.glob('/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/corr-transfus_yes-Insurance-1.0-Theil*.csv'):
    corr_T = pd.read_csv(f, index_col=0)
for f in glob.glob('/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/corr-transfus_yes-Insurance-1.0-Cramer*.csv'):
    corr_C = pd.read_csv(f, index_col=0)
for f in glob.glob('/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/rank-transfus_yes-Insurance-1.0-Theil*.csv'):
    rank_T = pd.read_csv(f, index_col=0)
for f in glob.glob('/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/rank-transfus_yes-Insurance-1.0-Cramer*.csv'):
    rank_C = pd.read_csv(f, index_col=0)

#for f in glob.glob('/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/corr-transfus_yes-high_Age-1.0-Theil*.csv'):
#    corr_T = pd.read_csv(f, index_col=0)
#for f in glob.glob('/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/corr-transfus_yes-high_Age-1.0-Cramer*.csv'):
#    corr_C = pd.read_csv(f, index_col=0)
#for f in glob.glob('/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/rank-transfus_yes-high_Age-1.0-Theil*.csv'):
#    rank_T = pd.read_csv(f, index_col=0)
#for f in glob.glob('/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/rank-transfus_yes-high_Age-1.0-Cramer*.csv'):
#    rank_C = pd.read_csv(f, index_col=0)

#for f in glob.glob('/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/corr-transfus_yes-momrace_new-1.0-Theil*.csv'):
#    corr_T = pd.read_csv(f, index_col=0)
#for f in glob.glob('/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/corr-transfus_yes-momrace_new-1.0-Cramer*.csv'):
#    corr_C = pd.read_csv(f, index_col=0)
#for f in glob.glob('/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/rank-transfus_yes-momrace_new-1.0-Theil*.csv'):
#    rank_T = pd.read_csv(f, index_col=0)
#for f in glob.glob('/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/rank-transfus_yes-momrace_new-1.0-Cramer*.csv'):
#    rank_C = pd.read_csv(f, index_col=0)

#for f in glob.glob('/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/corr-transfus_yes-RAND-1.0-Theil*.csv'):
#    corr_T = pd.read_csv(f, index_col=0)
#for f in glob.glob('/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/corr-transfus_yes-RAND-1.0-Cramer*.csv'):
#    corr_C = pd.read_csv(f, index_col=0)
#for f in glob.glob('/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/rank-transfus_yes-RAND-1.0-Theil*.csv'):
#    rank_T = pd.read_csv(f, index_col=0)
#for f in glob.glob('/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/rank-transfus_yes-RAND-1.0-Cramer*.csv'):
#    rank_C = pd.read_csv(f, index_col=0)

#for f in glob.glob('/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/corr-transfus_yes-NONE-1.0-Theil*.csv'):
#    corr_T = pd.read_csv(f, index_col=0)
#for f in glob.glob('/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/corr-transfus_yes-NONE-1.0-Cramer*.csv'):
#    corr_C = pd.read_csv(f, index_col=0)
#for f in glob.glob('/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/rank-transfus_yes-NONE-1.0-Theil*.csv'):
#    rank_T = pd.read_csv(f, index_col=0)
#for f in glob.glob('/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/rank-transfus_yes-NONE-1.0-Cramer*.csv'):
#    rank_C = pd.read_csv(f, index_col=0)

# %%
theil_rank_df = pd.DataFrame(rank_T['mean_rank'].rank().astype('int')).rename(columns={'mean_rank':'Theil_rank'})
theil_rank_df['Theil_corr'] = corr_T['mean_corr']
cramer_rank_df = pd.DataFrame(rank_C['mean_rank'].rank().astype('int')).rename(columns={'mean_rank':'Cramer_rank'})
cramer_rank_df['Cramer_corr'] = corr_C['mean_corr']
combined_rank = pd.merge(cramer_rank_df, theil_rank_df, left_index=True, right_index=True)
combined_rank.head(40)
# Out:
#                 Cramer_rank  Cramer_corr  Theil_rank  Theil_corr
# transfus_yes              1       0.9998           1      1.0000
# Inoxy_incrdose            2       0.4879           2      0.1894
# Intratocolytix            3       0.4376           3      0.1472
# Education                 4       0.4266           4      0.1379
# HospElectCS               5       0.4090           6      0.1269
# Admcontract               6       0.4077           5      0.1324
# HosEpiNurse               7       0.3629           8      0.1048
# DMControl                 8       0.3548           9      0.0958
# BESTGA                    9       0.3453           7      0.1149
# AdmBishop                10       0.2817          10      0.0591
# Hostype                  10       0.2841          11      0.0584
# Augment                  12       0.2644          13      0.0554
# HospElectInd             13       0.2596          14      0.0558
# ...

# %%
combined_rank.loc['Insurance']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/miniconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Insurance'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-39580be770fd> in <module>
# ----> 1 combined_rank['Insurance']
#
# ...

# %%
#filename = '/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/transfus_yes-Hostype-CramerTheil.csv'
#filename = '/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/transfus_yes-Insurance-CramerTheil.csv'
#filename = '/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/transfus_yes-high_Age-CramerTheil.csv'
#filename = '/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/transfus_yes-momrace_new-CramerTheil.csv'
#filename = '/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/transfus_yes-RAND-CramerTheil.csv'
#filename = '/slurm_storage/mbopf/projects/MFM_bopf/src/imbl/underCompOut/transfus_yes-NONE-CramerTheil.csv'
if not os.path.exists(filename):
    combined_rank.to_csv(filename)
